head(11)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819
# 2024-06-21  0.124430  0.125500  0.121617  0.124029   0.124029   598393023
# 2024-06-22  0.124038  0.125365  0.122959  0.123789   0.123789   328642106
# 2024-06-23  0.123783  0.126120  0.121827  0.122257   0.122257   429188641
# 2024-06-24  0.122249  0.123675  0.114731  0.119043   0.119043   951099440
# 2024-06-25  0.119033  0.128236  0.118895  0.126153   0.126153   783244352
# 2024-06-26  0.126150  0.128522  0.121920  0.122679   0.122679   526276880

# %%
H_XRP.head(11)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819
# 2024-06-21  0.124430  0.125500  0.121617  0.124029   0.124029   598393023
# 2024-06-22  0.124038  0.125365  0.122959  0.123789   0.123789   328642106
# 2024-06-23  0.123783  0.126120  0.121827  0.122257   0.122257   429188641
# 2024-06-24  0.122249  0.123675  0.114731  0.119043   0.119043   951099440
# 2024-06-25  0.119033  0.128236  0.118895  0.126153   0.126153   783244352
# 2024-06-26  0.126150  0.128522  0.121920  0.122679   0.122679   526276880

# %%
H_DOT.head(11)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819
# 2024-06-21  0.124430  0.125500  0.121617  0.124029   0.124029   598393023
# 2024-06-22  0.124038  0.125365  0.122959  0.123789   0.123789   328642106
# 2024-06-23  0.123783  0.126120  0.121827  0.122257   0.122257   429188641
# 2024-06-24  0.122249  0.123675  0.114731  0.119043   0.119043   951099440
# 2024-06-25  0.119033  0.128236  0.118895  0.126153   0.126153   783244352
# 2024-06-26  0.126150  0.128522  0.121920  0.122679   0.122679   526276880

# %%
H_ADA.head(11)
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819
# 2024-06-21  0.124430  0.125500  0.121617  0.124029   0.124029   598393023
# 2024-06-22  0.124038  0.125365  0.122959  0.123789   0.123789   328642106
# 2024-06-23  0.123783  0.126120  0.121827  0.122257   0.122257   429188641
# 2024-06-24  0.122249  0.123675  0.114731  0.119043   0.119043   951099440
# 2024-06-25  0.119033  0.128236  0.118895  0.126153   0.126153   783244352
# 2024-06-26  0.126150  0.128522  0.121920  0.122679   0.122679   526276880

# %%
DESTINO = H_BTC

# %%
DESTINO.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819

# %%
DF_BTC = DESTINO.rename(columns={'Date':'(BTC)Date','Open':'(BTC)Open', 'High':'(BTC)High','Low':'(BTC)Low','Close':'(BTC)Close','Adj Close':'(BTC)Adj Close','Volume':'(BTC)Volume'})

# %%
DF_DESTINO = H_ETH.rename(columns={'Date':'(ETH)Date','Open':'(ETH)Open', 'High':'(ETH)High','Low':'(ETH)Low','Close':'(ETH)Close','Adj Close':'(ETH)Adj Close','Volume':'(ETH)Volume'})

# %%
DF_DESTINO.head()
# Out:
#             (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  (ETH)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (ETH)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
DESTINO.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819

# %%
DF_BTC.head()
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (BTC)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
launcher = DF_BTC

# %%
launcher.head()
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (BTC)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
df_ETH = DESTINO

# %%
DF_DESTINO.head()
# Out:
#             (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  (ETH)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (ETH)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
df_eth = DF_DESTINO

# %%
df_eth.head()
# Out:
#             (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  (ETH)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (ETH)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
all_columns_list = df_eth.columns.values.tolist()
all_columns_list
# Out:
# ['(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume']

# %%
launcher.loc[:, ['(ETH)Open', '(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']] = df_eth.loc[:, ['(ETH)Open', '(ETH)High','(ETH)Low','(ETH)Close','(ETH)Adj Close','(ETH)Volume']]

# %%
launcher.head()
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  \
# Date
# 2024-06-16    385407083   0.136576   0.137347  0.134819    0.136937
# 2024-06-17    960646592   0.136940   0.138023  0.126495    0.128889
# 2024-06-18   1413960450   0.128866   0.129103  0.115392    0.122296
# 2024-06-19    642487745   0.122279   0.126508  0.121579    0.122341
# 2024-06-20    734399819   0.122341   0.128266  0.121454    0.124419
#
#             (ETH)Adj Close  (ETH)Volume
# Date
# 2024-06-16        0.136937    385407083
# ...

# %%
all_columns_list = launcher.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume']

# %%
H_XRP.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819

# %%
df_xrp = H_XRP.rename(columns={'Date':'(XRP)Date','Open':'(XRP)Open','High':'(XRP)High','Low':'(XRP)Low','Close':'(XRP)Close','Adj Close':'(XRP)Adj Close','Volume':'(XRP)Volume'})

# %%
df_xrp.head()
# Out:
#             (XRP)Open  (XRP)High  (XRP)Low  (XRP)Close  (XRP)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (XRP)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
launcher.loc[:, ['(XRP)Open', '(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']] = df_xrp.loc[:, ['(XRP)Open', '(XRP)High','(XRP)Low','(XRP)Close','(XRP)Adj Close','(XRP)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  \
# Date
# ...

# %%
hist_LTC.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2024-06-16  79.197708  80.002747  78.609398  78.905937  78.905937  213769033
# 2024-06-17  78.908035  79.160629  75.337883  76.626091  76.626091  374224288
# 2024-06-18  76.619247  76.675430  70.870773  72.616463  72.616463  615015988
# 2024-06-19  72.614571  74.879639  72.548477  73.703514  73.703514  294923125
# 2024-06-20  73.703514  75.292023  73.291885  74.708763  74.708763  328191289

# %%
H_LTC = hist_LTC.rename(columns={'Date':'(LTC)Date','Open':'(LTC)Open','High':'(LTC)High','Low':'(LTC)Low','Close':'(LTC)Close','Adj Close':'(LTC)Adj Close','Volume':'(LTC)Volume'})

# %%
H_LTC.head()
# Out:
#             (LTC)Open  (LTC)High   (LTC)Low  (LTC)Close  (LTC)Adj Close  \
# Date
# 2024-06-16  79.197708  80.002747  78.609398   78.905937       78.905937
# 2024-06-17  78.908035  79.160629  75.337883   76.626091       76.626091
# 2024-06-18  76.619247  76.675430  70.870773   72.616463       72.616463
# 2024-06-19  72.614571  74.879639  72.548477   73.703514       73.703514
# 2024-06-20  73.703514  75.292023  73.291885   74.708763       74.708763
#
#             (LTC)Volume
# Date
# 2024-06-16    213769033
# 2024-06-17    374224288
# 2024-06-18    615015988
# 2024-06-19    294923125
# 2024-06-20    328191289

# %%
launcher.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']] = H_LTC.loc[:,['(LTC)Open','(LTC)High','(LTC)Low','(LTC)Close','(LTC)Adj Close','(LTC)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
ticker = ("BCH-USD")
H_BCH= yf.download(ticker,start="2024-06-16",end="2024-07-16")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
H_BCH.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-16  429.719208  433.482513  426.697845  428.152985  428.152985
# 2024-06-17  428.143585  428.948395  405.641663  420.228485  420.228485
# 2024-06-18  420.183624  420.690979  373.450073  389.314880  389.314880
# 2024-06-19  389.297791  397.895386  385.556122  388.660278  388.660278
# 2024-06-20  388.660278  400.227478  385.939758  389.861938  389.861938
#
#                Volume
# Date
# 2024-06-16  172946681
# 2024-06-17  275760280
# 2024-06-18  413991010
# 2024-06-19  212059873
# 2024-06-20  227242865

# %%
pd_BCH = H_BCH.rename(columns={'Date':'(BCH)Date','Open':'(BCH)Open','High':'(BCH)High','Low':'(BCH)Low','Close':'(BCH)Close','Adj Close':'(BCH)Adj Close','Volume':'(BCH)Volume'})

# %%
pd_BCH.head()
# Out:
#              (BCH)Open   (BCH)High    (BCH)Low  (BCH)Close  (BCH)Adj Close  \
# Date
# 2024-06-16  429.719208  433.482513  426.697845  428.152985      428.152985
# 2024-06-17  428.143585  428.948395  405.641663  420.228485      420.228485
# 2024-06-18  420.183624  420.690979  373.450073  389.314880      389.314880
# 2024-06-19  389.297791  397.895386  385.556122  388.660278      388.660278
# 2024-06-20  388.660278  400.227478  385.939758  389.861938      389.861938
#
#             (BCH)Volume
# Date
# 2024-06-16    172946681
# 2024-06-17    275760280
# 2024-06-18    413991010
# 2024-06-19    212059873
# 2024-06-20    227242865

# %%
launcher.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume' ]] = pd_BCH.loc[:,['(BCH)Open','(BCH)High','(BCH)Low','(BCH)Close','(BCH)Adj Close','(BCH)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
all_columns_list = launcher.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume']

# %%
pd_ADA = H_ADA.rename(columns={'Date':'(ADA)Date','Open':'(ADA)Open','High':'(ADA)High','Low':'(ADA)Low','Close':'(ADA)Close','Adj Close':'(ADA)Adj Close','Volume':'(ADA)Volume'})

# %%
pd_ADA.head()
# Out:
#             (ADA)Open  (ADA)High  (ADA)Low  (ADA)Close  (ADA)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (ADA)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
launcher.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']] = pd_ADA.loc[:,['(ADA)Open','(ADA)High','(ADA)Low','(ADA)Close','(ADA)Adj Close','(ADA)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
pd_DOT = H_DOT.rename(columns={'Date':'(DOT)Date','Open':'(DOT)Open','High':'(DOT)High','Low':'(DOT)Low','Close':'(DOT)Close','Adj Close':'(DOT)Adj Close','Volume':'(DOT)Volume'})

# %%
pd_DOT.head()
# Out:
#             (DOT)Open  (DOT)High  (DOT)Low  (DOT)Close  (DOT)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (DOT)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
launcher.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']] = pd_DOT.loc[:,['(DOT)Open','(DOT)High','(DOT)Low','(DOT)Close','(DOT)Adj Close','(DOT)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
HIST_BNB.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-16  607.808472  611.197510  601.476929  610.054016  610.054016
# 2024-06-17  610.073669  611.944031  592.426147  604.467346  604.467346
# 2024-06-18  604.332886  604.652832  575.761719  588.702087  588.702087
# 2024-06-19  588.584717  605.731689  587.014160  598.771729  598.771729
# 2024-06-20  598.771729  607.400757  584.759949  587.107178  587.107178
#
#                 Volume
# Date
# 2024-06-16  1428836675
# 2024-06-17  1797626078
# 2024-06-18  2265505402
# 2024-06-19  1788904109
# 2024-06-20  1817442036

# %%
dt_BNB = HIST_BNB.rename(columns={'Date':'(BNB)Date','Open':'(BNB)Open','High':'(BNB)High','Low':'(BNB)Low','Close':'(BNB)Close','Adj Close':'(BNB)Adj Close','Volume':'(BNB)Volume'})

# %%
dt_BNB.head()
# Out:
#              (BNB)Open   (BNB)High    (BNB)Low  (BNB)Close  (BNB)Adj Close  \
# Date
# 2024-06-16  607.808472  611.197510  601.476929  610.054016      610.054016
# 2024-06-17  610.073669  611.944031  592.426147  604.467346      604.467346
# 2024-06-18  604.332886  604.652832  575.761719  588.702087      588.702087
# 2024-06-19  588.584717  605.731689  587.014160  598.771729      598.771729
# 2024-06-20  598.771729  607.400757  584.759949  587.107178      587.107178
#
#             (BNB)Volume
# Date
# 2024-06-16   1428836675
# 2024-06-17   1797626078
# 2024-06-18   2265505402
# 2024-06-19   1788904109
# 2024-06-20   1817442036

# %%
launcher.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']] = dt_BNB.loc[:,['(BNB)Open','(BNB)High','(BNB)Low','(BNB)Close','(BNB)Adj Close','(BNB)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
H_DOGE.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819

# %%
df_DOGE = H_DOGE.rename(columns={'Date':'(DOGE)Date','Open':'(DOGE)Open','High':'(DOGE)High','Low':'(DOGE)Low','Close':'(DOGE)Close','Adj Close':'(DOGE)Adj Close','Volume':'(DOGE)Volume'})

# %%
df_DOGE.head()
# Out:
#             (DOGE)Open  (DOGE)High  (DOGE)Low  (DOGE)Close  (DOGE)Adj Close  \
# Date
# 2024-06-16    0.136576    0.137347   0.134819     0.136937         0.136937
# 2024-06-17    0.136940    0.138023   0.126495     0.128889         0.128889
# 2024-06-18    0.128866    0.129103   0.115392     0.122296         0.122296
# 2024-06-19    0.122279    0.126508   0.121579     0.122341         0.122341
# 2024-06-20    0.122341    0.128266   0.121454     0.124419         0.124419
#
#             (DOGE)Volume
# Date
# 2024-06-16     385407083
# 2024-06-17     960646592
# 2024-06-18    1413960450
# 2024-06-19     642487745
# 2024-06-20     734399819

# %%
launcher.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']] = df_DOGE.loc[:,['(DOGE)Open','(DOGE)High','(DOGE)Low','(DOGE)Close','(DOGE)Adj Close','(DOGE)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
ticker = ("SOL-USD")
HIST_SOL = yf.download(ticker,start="2024-06-16", end="2024-07-16")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
HIST_SOL.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-16  145.417969  151.125504  143.179535  151.125504  151.125504
# 2024-06-17  151.137238  151.584778  140.138809  143.334274  143.334274
# 2024-06-18  143.314697  143.610657  130.289078  137.503998  137.503998
# 2024-06-19  137.479813  141.669937  134.732635  135.609604  135.609604
# 2024-06-20  135.609604  141.075241  132.087646  133.472961  133.472961
#
#                 Volume
# Date
# 2024-06-16  1147997523
# 2024-06-17  2244770232
# 2024-06-18  4046511952
# 2024-06-19  2241396569
# 2024-06-20  2343938226

# %%
df_SOL = HIST_SOL.rename(columns={'Date':'(SOL)Date','Open':'(SOL)Open','High':'(SOL)High','Low':'(SOL)Low','Close':'(SOL)Close','Adj Close':'(SOL)Adj Close','Volume':'(SOL)Volume'})

# %%
df_SOL.head()
# Out:
#              (SOL)Open   (SOL)High    (SOL)Low  (SOL)Close  (SOL)Adj Close  \
# Date
# 2024-06-16  145.417969  151.125504  143.179535  151.125504      151.125504
# 2024-06-17  151.137238  151.584778  140.138809  143.334274      143.334274
# 2024-06-18  143.314697  143.610657  130.289078  137.503998      137.503998
# 2024-06-19  137.479813  141.669937  134.732635  135.609604      135.609604
# 2024-06-20  135.609604  141.075241  132.087646  133.472961      133.472961
#
#             (SOL)Volume
# Date
# 2024-06-16   1147997523
# 2024-06-17   2244770232
# 2024-06-18   4046511952
# 2024-06-19   2241396569
# 2024-06-20   2343938226

# %%
H_XLM.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2024-06-16  0.098245  0.099143  0.097647  0.098995   0.098995   33153627
# 2024-06-17  0.099006  0.099279  0.095565  0.096912   0.096912   89787741
# 2024-06-18  0.096901  0.096947  0.088100  0.091372   0.091372  133004372
# 2024-06-19  0.091373  0.094101  0.090736  0.093305   0.093305   51932569
# 2024-06-20  0.093305  0.095393  0.093062  0.093913   0.093913   51643502

# %%
df_XLM = H_XLM.rename(columns={'Date':'(XLM)Date','Open':'(XLM)Open','High':'(XLM)High','Low':'(XLM)Low','Close':'(XLM)Close','Adj Close':'(XLM)Adj Close','Volume':'(XLM)Volume'})

# %%
df_XLM.head()
# Out:
#             (XLM)Open  (XLM)High  (XLM)Low  (XLM)Close  (XLM)Adj Close  \
# Date
# 2024-06-16   0.098245   0.099143  0.097647    0.098995        0.098995
# 2024-06-17   0.099006   0.099279  0.095565    0.096912        0.096912
# 2024-06-18   0.096901   0.096947  0.088100    0.091372        0.091372
# 2024-06-19   0.091373   0.094101  0.090736    0.093305        0.093305
# 2024-06-20   0.093305   0.095393  0.093062    0.093913        0.093913
#
#             (XLM)Volume
# Date
# 2024-06-16     33153627
# 2024-06-17     89787741
# 2024-06-18    133004372
# 2024-06-19     51932569
# 2024-06-20     51643502

# %%
launcher.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']] = df_XLM.loc[:,['(XLM)Open','(XLM)High','(XLM)Low','(XLM)Close','(XLM)Adj Close','(XLM)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
launcher.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']] = df_SOL.loc[:,['(SOL)Open','(SOL)High','(SOL)Low','(SOL)Close','(SOL)Adj Close','(SOL)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
H_USDT.head()
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 2024-06-16  0.999438  1.000105  0.999039  0.999293   0.999293  31962850043
# 2024-06-17  0.999341  1.000182  0.999004  0.999645   0.999645  60712949361
# 2024-06-18  0.999650  1.001334  0.999308  0.999550   0.999550  78695656625
# 2024-06-19  0.999595  1.000510  0.999326  0.999796   0.999796  48283435769
# 2024-06-20  0.999796  1.000535  0.999002  0.999399   0.999399  53052487180

# %%
df_USDT = H_USDT.rename(columns={'Open':'(USDT)Open','High':'(USDT)High','Low':'(USDT)Low','Close':'(USDT)Close','Adj Close':'(USDT)Adj Close','Volume':'(USDT)Volume'})

# %%
df_USDT.head()
# Out:
#             (USDT)Open  (USDT)High  (USDT)Low  (USDT)Close  (USDT)Adj Close  \
# Date
# 2024-06-16    0.999438    1.000105   0.999039     0.999293         0.999293
# 2024-06-17    0.999341    1.000182   0.999004     0.999645         0.999645
# 2024-06-18    0.999650    1.001334   0.999308     0.999550         0.999550
# 2024-06-19    0.999595    1.000510   0.999326     0.999796         0.999796
# 2024-06-20    0.999796    1.000535   0.999002     0.999399         0.999399
#
#             (USDT)Volume
# Date
# 2024-06-16   31962850043
# 2024-06-17   60712949361
# 2024-06-18   78695656625
# 2024-06-19   48283435769
# 2024-06-20   53052487180

# %%
launcher.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']] = df_USDT.loc[:,['(USDT)Open','(USDT)High','(USDT)Low','(USDT)Close','(USDT)Adj Close','(USDT)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
H_UNI.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2024-06-16  0.136576  0.137347  0.134819  0.136937   0.136937   385407083
# 2024-06-17  0.136940  0.138023  0.126495  0.128889   0.128889   960646592
# 2024-06-18  0.128866  0.129103  0.115392  0.122296   0.122296  1413960450
# 2024-06-19  0.122279  0.126508  0.121579  0.122341   0.122341   642487745
# 2024-06-20  0.122341  0.128266  0.121454  0.124419   0.124419   734399819

# %%
df_UNI = H_UNI.rename(columns={'Open':'(UNI)Open','High':'(UNI)High','Low':'(UNI)Low','Close':'(UNI)Close','Adj Close':'(UNI)Adj Close','Volume':'(UNI)Volume'})

# %%
df_UNI.head()
# Out:
#             (UNI)Open  (UNI)High  (UNI)Low  (UNI)Close  (UNI)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
#
#             (UNI)Volume
# Date
# 2024-06-16    385407083
# 2024-06-17    960646592
# 2024-06-18   1413960450
# 2024-06-19    642487745
# 2024-06-20    734399819

# %%
launcher.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']] = df_UNI.loc[:,['(UNI)Open','(UNI)High','(UNI)Low','(UNI)Close','(UNI)Adj Close','(UNI)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
hist_LINK.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2024-06-16  14.858387  15.203491  14.594245  15.126066  15.126066  205762702
# 2024-06-17  15.125912  15.192699  14.062859  14.534426  14.534426  347472612
# 2024-06-18  14.533723  14.583276  13.119523  13.967771  13.967771  537842068
# 2024-06-19  13.966908  14.482511  13.924068  14.334752  14.334752  271728905
# 2024-06-20  14.334752  14.820921  14.209382  14.259184  14.259184  270709807

# %%
df_LINK = hist_LINK.rename(columns={'Date':'(LINK)Date','Open':'(LINK)Open','High':'(LINK)High','Low':'(LINK)Low','Close':'(LINK)Close','Adj Close':'(LINK)Adj Close','Volume':'(LINK)Volume'})

# %%
df_LINK.head()
# Out:
#             (LINK)Open  (LINK)High  (LINK)Low  (LINK)Close  (LINK)Adj Close  \
# Date
# 2024-06-16   14.858387   15.203491  14.594245    15.126066        15.126066
# 2024-06-17   15.125912   15.192699  14.062859    14.534426        14.534426
# 2024-06-18   14.533723   14.583276  13.119523    13.967771        13.967771
# 2024-06-19   13.966908   14.482511  13.924068    14.334752        14.334752
# 2024-06-20   14.334752   14.820921  14.209382    14.259184        14.259184
#
#             (LINK)Volume
# Date
# 2024-06-16     205762702
# 2024-06-17     347472612
# 2024-06-18     537842068
# 2024-06-19     271728905
# 2024-06-20     270709807

# %%
launcher.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']] = df_LINK.loc[:,['(LINK)Open','(LINK)High','(LINK)Low','(LINK)Close','(LINK)Adj Close','(LINK)Volume']]

# %%
launcher.head(11)
# Out:
#             (BTC)Open  (BTC)High  (BTC)Low  (BTC)Close  (BTC)Adj Close  \
# Date
# 2024-06-16   0.136576   0.137347  0.134819    0.136937        0.136937
# 2024-06-17   0.136940   0.138023  0.126495    0.128889        0.128889
# 2024-06-18   0.128866   0.129103  0.115392    0.122296        0.122296
# 2024-06-19   0.122279   0.126508  0.121579    0.122341        0.122341
# 2024-06-20   0.122341   0.128266  0.121454    0.124419        0.124419
# 2024-06-21   0.124430   0.125500  0.121617    0.124029        0.124029
# 2024-06-22   0.124038   0.125365  0.122959    0.123789        0.123789
# 2024-06-23   0.123783   0.126120  0.121827    0.122257        0.122257
# 2024-06-24   0.122249   0.123675  0.114731    0.119043        0.119043
# 2024-06-25   0.119033   0.128236  0.118895    0.126153        0.126153
# 2024-06-26   0.126150   0.128522  0.121920    0.122679        0.122679
#
#             (BTC)Volume  (ETH)Open  (ETH)High  (ETH)Low  (ETH)Close  ...  \
# ...

# %%
all_columns_list = launcher.columns.values.tolist()
all_columns_list
# Out:
# ['(BTC)Open',
#  '(BTC)High',
#  '(BTC)Low',
#  '(BTC)Close',
#  '(BTC)Adj Close',
#  '(BTC)Volume',
#  '(ETH)Open',
#  '(ETH)High',
#  '(ETH)Low',
#  '(ETH)Close',
#  '(ETH)Adj Close',
#  '(ETH)Volume',
#  '(XRP)Open',
#  '(XRP)High',
#  '(XRP)Low',
#  '(XRP)Close',
#  '(XRP)Adj Close',
#  '(XRP)Volume',
#  '(LTC)Open',
#  '(LTC)High',
#  '(LTC)Low',
#  '(LTC)Close',
#  '(LTC)Adj Close',
#  '(LTC)Volume',
#  '(BCH)Open',
#  '(BCH)High',
#  '(BCH)Low',
#  '(BCH)Close',
#  '(BCH)Adj Close',
#  '(BCH)Volume',
#  '(ADA)Open',
#  '(ADA)High',
#  '(ADA)Low',
#  '(ADA)Close',
#  '(ADA)Adj Close',
#  '(ADA)Volume',
#  '(DOT)Open',
#  '(DOT)High',
#  '(DOT)Low',
#  '(DOT)Close',
#  '(DOT)Adj Close',
#  '(DOT)Volume',
#  '(BNB)Open',
#  '(BNB)High',
#  '(BNB)Low',
#  '(BNB)Close',
#  '(BNB)Adj Close',
#  '(BNB)Volume',
#  '(DOGE)Open',
#  '(DOGE)High',
#  '(DOGE)Low',
#  '(DOGE)Close',
#  '(DOGE)Adj Close',
#  '(DOGE)Volume',
#  '(XLM)Open',
#  '(XLM)High',
#  '(XLM)Low',
#  '(XLM)Close',
# ...
